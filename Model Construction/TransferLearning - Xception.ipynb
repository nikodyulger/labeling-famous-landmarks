# %% [markdown]
# # Labelling Famous Landmarks (Transfer Learning)
#
# This notebook shows up one of the neural network model implementation for my data science project about the **Google Landmark Recognition 2020** dataset. The main objective with this step is applying transfer learning, carrying on the  hyperparameter tuning of the model and finally evaluating the results.

# %% [markdown]
# # Index of Contents
#
# 1.   Loading modules and data
# 2.   Preprocessing data
# 3.   Model Construction
# 4.   Evaluation

# %% [markdown]
# # Loading modules and data

# %% [markdown]
# Since I am using Google Colab, I linked my Google Drive just to access all the data downloaded from Kaggle. Also, by this way all the result and created files are easily stored on my unit.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# For the model implementation I will make use of **Keras** library due to its simplicity and large community support.

# %%
from keras.preprocessing import image_dataset_from_directory
from keras.applications import Xception
from keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout
from keras.layers.experimental.preprocessing import Rescaling, RandomZoom, RandomFlip, RandomRotation, RandomTranslation
from keras.models import Sequential, Model
from keras.optimizers import Adam, RMSprop
from keras.losses import CategoricalCrossentropy
from keras.metrics import Accuracy,  CategoricalAccuracy
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard

# %%
from tensorboard.plugins.hparams import api as hp
from sklearn.utils import class_weight
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import datetime
import tensorflow as tf

# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %% [markdown]
# Checking the availability of the Google Colab free GPU for the model training.

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# Extracting all the images from the Google Drive unit with which the model will be feeded.

# %%
! unzip -qq '/content/drive/MyDrive/4º de Carrera/TFG/train_200.zip'
! unzip -qq '/content/drive/MyDrive/4º de Carrera/TFG/val_200.zip'
! unzip -qq '/content/drive/MyDrive/4º de Carrera/TFG/test_200.zip'

# %% [markdown]
# Checking is everything is done correctly.

# %%
! ls -a
# Out:
# .  ..  .config	drive  sample_data  ..test_200	..train_200  ..val_200

# %% [markdown]
# Set a seed to make reproducible experiments.

# %%
seed = 487

# %%
train_csv = pd.read_csv("/content/drive/MyDrive/4º de Carrera/TFG/train_200.csv")
train_csv.sample(5, random_state=seed)
# Out:
#                      id  ...                                               path
# 40243  d8c9f411e80e0b62  ...  ../input/landmark-recognition-2020/train/d/8/c...
# 43574  e5988cfafb9152d4  ...  ../input/landmark-recognition-2020/train/e/5/9...
# 5018   40a0c51d75e33888  ...  ../input/landmark-recognition-2020/train/4/0/a...
# 39121  4ec75514a3a8bc71  ...  ../input/landmark-recognition-2020/train/4/e/c...
# 53026  81c1d9b7f0868434  ...  ../input/landmark-recognition-2020/train/8/1/c...
#
# [5 rows x 3 columns]

# %% [markdown]
# # Preprocessing data

# %% [markdown]
# Before starting with the model construction, it is convenient to prepare the data.

# %%
CLASSES = 200
BATCH_SIZE = 256
IMG_SIZE = (128, 128)
DATA_FORMAT = "channels_last"

# %%
train_dir = "..train_200"
train_dataset = image_dataset_from_directory(train_dir,
                                             shuffle=True,
                                             label_mode='categorical',
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE,
                                             seed=seed)

val_dir = "..val_200"
val_dataset = image_dataset_from_directory(val_dir,
                                           shuffle=False,
                                           label_mode='categorical',
                                           batch_size=BATCH_SIZE,
                                           image_size=IMG_SIZE,
                                           seed=seed)
# Out:
# Found 54761 files belonging to 200 classes.
# Found 15446 files belonging to 200 classes.
# Found 7801 files belonging to 200 classes.

# %% [markdown]
# Let's previsualize some bunch of photos from the train dataset, to check everything is loaded correctly.

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(f"Class name [{class_names[np.argmax(labels[i])]}]")
    plt.axis("off")

# %% [markdown]
# To load images from disk without I/O being blocked and boost the performance, it is highly recommended to use the buffered prefetching feature AUTOTUNE.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Data augmentation
# After several disastrous attempts of training the models with only the original images, I supposed that data augmentation technique could be one of the clues for improving the performance. Although the dataset is big enough, its special characteristic (intra-class variance) make the training process difficult to extract common features. The hypothesis that I came up with is that as every image is unique in each class, the model needs more examples to learn from. So, the idea is to generate on the fly "augmented" images from the original ones to facilitate more similar examples to the network in order to boost its accuracy.

# %%
data_augmentation = Sequential([
      RandomFlip("horizontal"),
      RandomZoom(0.2,0.2),
      RandomRotation(0.2),                        
], name="data_augmentation")

# %% [markdown]
# There are different ways of performing data augmentation with Keras, I ahve opted to make use of the experimental preprocessing layers instead of the classical ImageDataGenerator class. Let's see the result with some random photos.

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %% [markdown]
# Another important thing to consider is rescaling the pixel values, so let's create a separate layer for that specific task.

# %%
rescale = Sequential([
      Rescaling(1./255)
], name="rescale")

# %% [markdown]
# # Model Construction
# Now it is time to build the model and for that I am going to use **Xception** as a base model. It is one of the different pre-trained models available on Keras. This tecnhique is called transfer learning because we are going to take the knowledge extracted from one dataset (ImageNet) and applied it to classify images from our.

# %% [markdown]
# The first thing to do is load all the weights and freeze all the layers.

# %%
pretrained_model = Xception(include_top=False, 
                            weights="imagenet",
                            input_shape=(*IMG_SIZE,3))
pretrained_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 2s 0us/step

# %% [markdown]
# Once created the pretrained model, we need to create the customized layers for our case. This part is known as the top block or classification head.

# %%
# Create new model on top.
inputs = Input(shape=(*IMG_SIZE,3))
x = rescale(inputs)
x = data_augmentation(x)
x = pretrained_model(x, training=False)
# x = GlobalAveragePooling2D()(x)
x = Flatten(data_format=DATA_FORMAT)(x)
x = Dense(512, "relu")(x)
x = Dropout(0.5)(x)
outputs = Dense(CLASSES, "softmax")(x)
model = Model(inputs, outputs)

# %% [markdown]
# Although the imbalance among classes was reduces on the **Data Cleaning** process, an significant gap stills remaining. The  weights for each class are calculated to make a better balanced and ensure a more accurate update of the neural network weights.

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(train_csv.landmark_id),
                                                 train_csv.landmark_id)
class_weights = dict(enumerate(class_weights))
print(class_weights)
# Out:
# {0: 0.784541547277937, 1: 0.784541547277937, 2: 1.2502511415525115, 3: 1.25598623853211, 4: 1.06955078125, 5: 0.784541547277937, 6: 1.2676157407407407, 7: 0.784541547277937, 8: 1.1130284552845529, 9: 1.1175714285714287, 10: 0.784541547277937, 11: 0.9126833333333333, 12: 1.0612596899224807, 13: 0.7936376811594202, 14: 1.0140925925925925, 15: 1.09522, 16: 0.784541547277937, 17: 0.784541547277937, 18: 1.0737450980392156, 19: 1.1130284552845529, 20: 1.2502511415525115, 21: 0.784541547277937, 22: 1.1801939655172413, 23: 1.2061894273127753, 24: 0.784541547277937, 25: 1.2915330188679246, 26: 0.8029472140762464, 27: 0.9344880546075085, 28: 0.8424769230769231, 29: 0.8692222222222222, 30: 0.784541547277937, 31: 1.1956550218340611, 32: 1.1956550218340611, 33: 1.27946261682243, 34: 1.2008991228070176, 35: 1.261774193548387, 36: 1.126769547325103, 37: 0.784541547277937, 38: 0.784541547277937, 39: 0.9709397163120568, 40: 1.126769547325103, 41: 0.8637381703470032, 42: 0.784541547277937, 43: 1.155295358649789, 44: 0.784541547277937, 45: 0.784541547277937, 46: 1.2735116279069767, 47: 1.3038333333333334, 48: 1.1701068376068375, 49: 0.9849100719424461, 50: 0.784541547277937, 51: 0.784541547277937, 52: 1.1130284552845529, 53: 0.784541547277937, 54: 1.216911111111111, 55: 1.1361203319502076, 56: 0.8947875816993464, 57: 0.784541547277937, 58: 1.2735116279069767, 59: 1.2008991228070176, 60: 1.2915330188679246, 61: 1.126769547325103, 62: 1.25598623853211, 63: 1.2115265486725664, 64: 1.3038333333333334, 65: 1.2676157407407407, 66: 1.2061894273127753, 67: 0.784541547277937, 68: 1.1085222672064778, 69: 1.2445681818181817, 70: 1.3100717703349283, 71: 0.9992883211678832, 72: 1.1701068376068375, 73: 1.2008991228070176, 74: 0.9540243902439024, 75: 0.9157357859531773, 76: 1.1801939655172413, 77: 1.1130284552845529, 78: 0.8173283582089552, 79: 1.1651276595744682, 80: 1.010350553505535, 81: 0.784541547277937, 82: 1.297654028436019, 83: 0.784541547277937, 84: 0.8247138554216867, 85: 0.784541547277937, 86: 1.2061894273127753, 87: 0.784541547277937, 88: 1.0254868913857678, 89: 1.216911111111111, 90: 1.0908565737051792, 91: 1.2389366515837104, 92: 1.233355855855856, 93: 1.0822332015810276, 94: 1.1361203319502076, 95: 0.9157357859531773, 96: 1.297654028436019, 97: 1.2445681818181817, 98: 0.784541547277937, 99: 1.0653891050583657, 100: 0.9219023569023569, 101: 1.2008991228070176, 102: 0.784541547277937, 103: 1.2676157407407407, 104: 0.8222372372372372, 105: 1.1085222672064778, 106: 0.784541547277937, 107: 0.9813799283154122, 108: 1.25598623853211, 109: 0.784541547277937, 110: 1.1601906779661018, 111: 1.2389366515837104, 112: 0.784541547277937, 113: 1.2389366515837104, 114: 0.8100739644970414, 115: 1.1601906779661018, 116: 1.2389366515837104, 117: 1.3038333333333334, 118: 0.784541547277937, 119: 1.1956550218340611, 120: 1.2389366515837104, 121: 1.1175714285714287, 122: 1.2445681818181817, 123: 1.1085222672064778, 124: 1.029342105263158, 125: 1.0996184738955823, 126: 0.784541547277937, 127: 1.0371401515151515, 128: 0.8029472140762464, 129: 1.1221516393442623, 130: 1.216911111111111, 131: 0.9157357859531773, 132: 0.855640625, 133: 1.1801939655172413, 134: 0.784541547277937, 135: 1.2735116279069767, 136: 1.2676157407407407, 137: 0.784541547277937, 138: 1.06955078125, 139: 1.3038333333333334, 140: 1.261774193548387, 141: 1.1504411764705882, 142: 0.8148958333333334, 143: 0.784541547277937, 144: 1.297654028436019, 145: 0.784541547277937, 146: 1.233355855855856, 147: 1.0653891050583657, 148: 1.1130284552845529, 149: 1.3163701923076923, 150: 0.784541547277937, 151: 1.3038333333333334, 152: 1.1651276595744682, 153: 0.784541547277937, 154: 1.285469483568075, 155: 1.1904565217391305, 156: 1.1408541666666667, 157: 1.010350553505535, 158: 1.25598623853211, 159: 0.784541547277937, 160: 0.9096511627906977, 161: 0.784541547277937, 162: 0.9884657039711191, 163: 1.3038333333333334, 164: 1.261774193548387, 165: 0.8476934984520124, 166: 1.2061894273127753, 167: 0.9743950177935943, 168:  ...

# %% [markdown]
# The competition metric is a common point for comparing the results of the model. It is a guide to follow for the tuning process.
#
# $GAP = \frac{1}{M}\sum_{i=1}^N P(i) rel(i)$
#
# While searching how to code the formula I found several implementations, but not all were adapted for being used by Keras. So, I take one that was commonly used on different notebooks:
#
# *   [Landmark Recognition Challenge - jandaldrop](https://github.com/jandaldrop/landmark-recognition-challenge/blob/master/landmarks-xception.ipynb)
# *   [TF Keras EffNet B2 - Non Landmark Removal - Robert Smits](https://www.kaggle.com/rsmits/tf-keras-effnet-b2-non-landmark-removal)
#
# The GAP is estimated by calculating it on each batch during training.

# %%
def GAP(y_t, y_p):
    pred_cat = tf.argmax(y_p, axis=-1)    
    y_t_cat = tf.argmax(y_t, axis=-1) * tf.cast(
        tf.reduce_sum(y_t, axis=-1), tf.int64)
    
    n_pred = tf.shape(pred_cat)[0]
    is_c = tf.cast(tf.equal(pred_cat, y_t_cat), tf.float32)

    GAP = tf.reduce_mean(
          tf.cumsum(is_c) * is_c / tf.cast(
              tf.range(1, n_pred + 1), 
              dtype=tf.float32))
    
    return GAP

# %%
metrics = [GAP, "accuracy"]

EPOCHS = 25
LR = 1e-3

model.summary()
model.compile(optimizer=Adam(learning_rate=LR),
              loss=CategoricalCrossentropy(), 
              metrics=metrics)
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# rescale (Sequential)         (None, 128, 128, 3)       0
# _________________________________________________________________
# data_augmentation (Sequentia (None, 128, 128, 3)       0
# _________________________________________________________________
# xception (Functional)        (None, 4, 4, 2048)        20861480
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               16777728
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 20)                10260
# =================================================================
# Total params: 37,649,468
# Trainable params: 16,787,988
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %% [markdown]
# To train the model and keep track of what is happening inside this giant black box, it is a common practice to use checkpoints. They allow us to store valious information as the weights of the best models, the track of the metrics and other kind of parameters if they are needed.
#
# **TensorBoard** needs a special mention because it is a tool that makes things easy for the hyper-parameter tuning and also sharing with the community the results of the different experiments carried on.

# %%
#Dictionary as a log for the hyperparemeter tuning
hyperparameters = { 
    'classes': CLASSES,
    'img_size': IMG_SIZE[0],
    'optimizer': "Adam",
    'batch': BATCH_SIZE,
    'data_augmentation':True,
    'learning_rate': LR,
    'epochs': EPOCHS,
    'flatten': True, 
    'dense': CLASSES,
    'dense_1': 512,
    'dropout': 0.5
}
hyperparameters
# Out:
# {'batch': 256,
#  'classes': 20,
#  'data_augmentation': True,
#  'dense': 20,
#  'dense_1': 512,
#  'dropout': 0.5,
#  'epochs': 25,
#  'flatten': True,
#  'img_size': 128,
#  'learning_rate': 0.001,
#  'optimizer': 'Adam'}

# %%
LOG_PATH = "/content/drive/MyDrive/4º de Carrera/TFG/Experiments/log_Xception_feature_extraction.csv"
log_csv = pd.read_csv(LOG_PATH)
print(log_csv.shape)
# Out:
# (18, 20)

# %%
log_csv
# Out:
#     batch  classes  data_augmentation  ...  val_loss  flatten  dense_1
# 0   256.0    200.0                0.0  ...     2.247      NaN      NaN
# 1   256.0    200.0                0.0  ...     2.201      NaN      NaN
# 2   256.0    200.0                0.0  ...     1.802      1.0      NaN
# 3   256.0    200.0                0.0  ...     3.980      1.0      NaN
# 4   256.0    200.0                0.0  ...     1.783      1.0    512.0
# 5   256.0    200.0                1.0  ...     2.111      1.0      NaN
# 6   256.0    200.0                1.0  ...     2.244      1.0    512.0
# 7   128.0    200.0                1.0  ...     7.084      1.0      NaN
# 8   512.0    200.0                1.0  ...     3.414      1.0      NaN
# 9   512.0    100.0                0.0  ...     1.677      1.0      NaN
# 10  256.0     20.0                0.0  ...     0.742      1.0      NaN
# 11  256.0     20.0                0.0  ...     0.673      0.0      NaN
# 12  256.0     20.0                0.0  ...     0.670      1.0    512.0
# 13  256.0     20.0                0.0  ...     0.691      1.0    512.0
# 14  256.0     20.0                0.0  ...     0.689      1.0    512.0
# 15  256.0     20.0                1.0  ...     0.706      1.0    512.0
# 16  256.0     20.0                1.0  ...     0.779      1.0      NaN
# 17  256.0     20.0                1.0  ...     1.049      1.0      NaN
#
# [18 rows x 20 columns]

# %%
NUM_EXPERIMENT = log_csv.shape[0] #index of the last experiment
LOG_DIR = f"/content/drive/MyDrive/4º de Carrera/TFG/TensorBoard_Logs/Xception_feature_extraction_{NUM_EXPERIMENT}"
CHECK_POINT = f"/content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_{NUM_EXPERIMENT}.h5"

callbacks = [
      EarlyStopping(monitor="val_accuracy", verbose=1, patience=3, mode="max", restore_best_weights=True), 
      ModelCheckpoint(filepath=CHECK_POINT, verbose=1, monitor="val_accuracy", mode="max", save_best_only=True),
      TensorBoard(log_dir=LOG_DIR, histogram_freq=1),
      hp.KerasCallback(LOG_DIR, hyperparameters)
]

with tf.device('/device:GPU:0'):
  history = model.fit(train_dataset,
                      epochs=EPOCHS,
                      callbacks=callbacks,
                      class_weight=class_weights,
                      validation_data=val_dataset)
# Out:
# Epoch 1/25
# 50/50 [==============================] - 49s 888ms/step - loss: 3.7654 - GAP: 0.0993 - accuracy: 0.2868 - val_loss: 1.2549 - val_GAP: 0.4087 - val_accuracy: 0.6355
#
# Epoch 00001: val_accuracy improved from -inf to 0.63555, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5
# Epoch 2/25
# 50/50 [==============================] - 45s 864ms/step - loss: 1.6850 - GAP: 0.2574 - accuracy: 0.5033 - val_loss: 1.0965 - val_GAP: 0.4481 - val_accuracy: 0.6600
#
# Epoch 00002: val_accuracy improved from 0.63555 to 0.66001, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5
# Epoch 3/25
# 50/50 [==============================] - 45s 866ms/step - loss: 1.5616 - GAP: 0.2989 - accuracy: 0.5377 - val_loss: 1.0813 - val_GAP: 0.4452 - val_accuracy: 0.6625
#
# Epoch 00003: val_accuracy improved from 0.66001 to 0.66254, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5
# Epoch 4/25
# 50/50 [==============================] - 45s 868ms/step - loss: 1.4696 - GAP: 0.3208 - accuracy: 0.5615 - val_loss: 1.0325 - val_GAP: 0.4764 - val_accuracy: 0.6870
#
# Epoch 00004: val_accuracy improved from 0.66254 to 0.68701, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5
# Epoch 5/25
# 50/50 [==============================] - 44s 855ms/step - loss: 1.3992 - GAP: 0.3466 - accuracy: 0.5819 - val_loss: 0.9581 - val_GAP: 0.5109 - val_accuracy: 0.7129
#
# Epoch 00005: val_accuracy improved from 0.68701 to 0.71288, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5
# Epoch 6/25
# 50/50 [==============================] - 44s 848ms/step - loss: 1.4051 - GAP: 0.3422 - accuracy: 0.5796 - val_loss: 0.9909 - val_GAP: 0.5045 - val_accuracy: 0.7058
#
# Epoch 00006: val_accuracy did not improve from 0.71288
# Epoch 7/25
# 50/50 [==============================] - 44s 861ms/step - loss: 1.3533 - GAP: 0.3594 - accuracy: 0.5912 - val_loss: 0.9410 - val_GAP: 0.5112 - val_accuracy: 0.7137
#
# Epoch 00007: val_accuracy improved from 0.71288 to 0.71372, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5
# Epoch 8/25
# 50/50 [==============================] - 45s 865ms/step - loss: 1.3114 - GAP: 0.3630 - accuracy: 0.6017 - val_loss: 0.9403 - val_GAP: 0.5086 - val_accuracy: 0.7132
#
# Epoch 00008: val_accuracy did not improve from 0.71372
# Epoch 9/25
# 50/50 [==============================] - 45s 864ms/step - loss: 1.2432 - GAP: 0.3961 - accuracy: 0.6233 - val_loss: 0.9383 - val_GAP: 0.5120 - val_accuracy: 0.7146
#
# Epoch 00009: val_accuracy improved from 0.71372 to 0.71457, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5
# Epoch 10/25
# 50/50 [==============================] - 45s 866ms/step - loss: 1.2316 - GAP: 0.3928 - accuracy: 0.6204 - val_loss: 0.9024 - val_GAP: 0.5170 - val_accuracy: 0.7216
#
# Epoch 00010: val_accuracy improved from 0.71457 to 0.72160, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5
# Epoch 11/25
# 50/50 [==============================] - 45s 866ms/step - loss: 1.1789 - GAP: 0.4078 - accuracy: 0.6329 - val_loss: 0.8929 - val_GAP: 0.5268 - val_accuracy: 0.7258
#
# Epoch 00011: val_accuracy improved from 0.72160 to 0.72582, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5
# Epoch 12/25
# 50/50 [==============================] - 45s 865ms/step - loss: 1.2082 - GAP: 0.4025 - accuracy: 0.6312 - val_loss: 0.8956 - val_GAP: 0.5274 - val_accuracy: 0.7238
#
# Epoch 00012: val_accuracy did not improve from 0.72582
# Epoch 13/25
# 50/50 [==============================] - 44s 863ms/step - loss: 1.1704 - GAP: 0.4143 - accuracy: 0.6353 - val_loss: 0.8647 - val_GAP: 0.5323 - val_accuracy: 0.7298
#
# Epoch 00013: val_accuracy improved from 0.72582 to 0.72975, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5
# Epoch 14/25
# 50/50 [==============================] - 44s 864ms/step - loss: 1.1974 - GAP: 0.4034 - accuracy: 0.6328 - val_loss: 0.8743 - val_GAP: 0.5370 - val_accuracy: 0.7323
#
# Epoch 00014: val_accuracy improved from 0.72975 to 0.73228, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5
# Epoch 15/25
# 50/50 [==============================] - 44s 864ms/step - loss: 1.1660 - GAP: 0.4278 - accuracy: 0.6464 - val_loss: 0.8894 - val_GAP: 0.5269 - val_accuracy: 0.7236
#
# Epoch 00015: val_accuracy did not improve from 0.73228
# Epoch 16/25
# 50/50 [==============================] - 45s 865ms/step - loss: 1.1482 - GAP: 0.4226 - accuracy: 0.6442 - val_loss: 0.8581 - val_GAP: 0.5423 - val_accuracy: 0.7331
#
# Epoch 00016: val_accuracy improved from 0.73228 to 0.73313, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5
# Epoch 17/25
# 50/50 [==============================] - 44s 861ms/step - loss: 1.1297 - GAP: 0.4444 - accuracy: 0.6545 - val_loss: 0.8365 - val_GAP: 0.5502 - val_accuracy: 0.7435
#
# Epoch 00017: val_accuracy improved from 0.73313 to 0.74353, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5
# Epoch 18/25
# 50/50 [==============================] - 45s 864ms/step - loss: 1.1029 - GAP: 0.4431 - accuracy: 0.6639 - val_loss: 0.8505 - val_GAP: 0.5408 - val_accuracy: 0.7348
#
# Epoch 00018: val_accuracy did not improve from 0.74353
# Epoch 19/25
# 50/50 [==============================] - 45s 866ms/step - loss: 1.1106 - GAP: 0.4390 - accuracy: 0.6616 - val_loss: 0.8312 - val_GAP: 0.5533 - val_accuracy: 0.7438
#
# Epoch 00019: val_accuracy improved from 0.74353 to 0.74381, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5
# Epoch 20/25
# 50/50 [==============================] - 44s 863ms/step - loss: 1.1035 - GAP: 0.4508 - accuracy: 0.6648 - val_loss: 0.8600 - val_GAP: 0.5374 - val_accuracy: 0.7320
#
# Epoch 00020: val_accuracy did not improve from 0.74381
# Epoch 21/25
# 50/50 [==============================] - 43s 844ms/step - loss: 1.0784 - GAP: 0.4683 - accuracy: 0.6765 - val_loss: 0.8300 - val_GAP: 0.5441 - val_accuracy: 0.7388
#
# Epoch 00021: val_accuracy did not improve from 0.74381
# Epoch 22/25
# 50/50 [==============================] - 44s 858ms/step - loss: 1.0772 - GAP: 0.4438 - accuracy: 0.6658 - val_loss: 0.8075 - val_GAP: 0.5528 - val_accuracy: 0.7407
# Restoring model weights from the end of the best epoch.
#
# Epoch 00022: val_accuracy did not improve from 0.74381
# Epoch 00022: early stopping

# %%
train_loss, train_gap, train_acc = model.evaluate(train_dataset)
# Out:
# 50/50 [==============================] - 33s 631ms/step - loss: 0.6935 - GAP: 0.6159 - accuracy: 0.7829

# %%
val_loss, val_gap, val_acc = model.evaluate(val_dataset)
# Out:
# 14/14 [==============================] - 9s 643ms/step - loss: 0.8312 - GAP: 0.5533 - accuracy: 0.7438

# %%
results = {
    'train_loss': round(train_loss,3) ,
    'train_acc': round(train_acc,3),
    'train_GAP': round(train_gap,3),
    'val_loss': round(val_loss,3),
    'val_acc': round(val_acc,3),
    'val_GAP': round(val_gap,3),
    'model': CHECK_POINT,
    'tensorboard': LOG_DIR
}
results
# Out:
# {'model': '/content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_feature_extraction_18.h5',
#  'tensorboard': '/content/drive/MyDrive/4º de Carrera/TFG/TensorBoard_Logs/Xception_feature_extraction_18',
#  'train_GAP': 0.616,
#  'train_acc': 0.783,
#  'train_loss': 0.694,
#  'val_GAP': 0.553,
#  'val_acc': 0.744,
#  'val_loss': 0.831}

# %%
log = {}
log.update(hyperparameters)
log.update(results)
# log_csv = pd.DataFrame() #Comment later
log_csv = log_csv.append(log, ignore_index=True)
print(log_csv.shape)
log_csv.to_csv(LOG_PATH, index=False)
# Out:
# (19, 20)

# %% [markdown]
# Once the model is trained, let's take a look to its performance through its history. The analysis give us clues about how well the model has learned, if it has overfit or underfit. In other words, it is the proof we have to make changes on the parameters.

# %%
def plot_history(history):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  gap = history.history['GAP']
  val_gap = history.history['val_GAP']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  plt.figure(figsize=(7, 10))
  plt.subplot(3, 1, 1)
  plt.plot(acc, label='Training Accuracy')
  plt.plot(val_acc, label='Validation Accuracy',  linestyle='dashed', color="red")
  plt.legend(loc='lower right')
  plt.ylabel('Accuracy')
  plt.title('Training and Validation Accuracy')

  plt.subplot(3, 1, 2)
  plt.plot(gap, label='Training GAP')
  plt.plot(val_gap, label='Validation GAP', linestyle='dashed', color="red")
  plt.legend(loc='lower right')
  plt.ylabel('GAP')
  plt.title('Training and Validation GAP')

  plt.subplot(3, 1, 3)
  plt.plot(loss, label='Training Loss')
  plt.plot(val_loss, label='Validation Loss',  linestyle='dashed', color="red")
  plt.legend(loc='upper right')
  plt.ylabel('Cross Entropy')
  plt.title('Training and Validation Loss')
  plt.xlabel('epoch')
  
  plt.show()

# %%
plot_history(history)

# %% [markdown]
# Another way of increasing the performance of the model is performing what is called a **fine-tuning** process. It is a tecnique that trains the weights of the pretrained model, "tuning" them or specializing them to the images of the current database. It is not recommended to unfreeze the entire model, just some of the top layers which are the most specialized.  Rather than overwriting the generic learning, fine-tuning aims to adapt these specialized features to work with the our dataset.

# %%
# Create new model on top.
inputs = Input(shape=(*IMG_SIZE,3))
x = rescale(inputs)
# x = data_augmentation(x)
x = pretrained_model(x, training=False)
# x = GlobalAveragePooling2D()(x)
x = Flatten(data_format=DATA_FORMAT)(x)
# x = Dense(512, "relu")(x)
# x = Dropout(0.5)(x)
x = Dense(512, "relu")(x)
x = Dropout(0.5)(x)
outputs = Dense(CLASSES, "softmax")(x)
model = Model(inputs, outputs)

# %%
pretrained_model.trainable = True

print("Number of layers in the pretrained model: ", len(pretrained_model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 130

# Freeze all the layers before the `fine_tune_at` layer
for layer in pretrained_model.layers[:fine_tune_at]:
  layer.trainable =  False

FINE_TUNE_EPOCHS = 40

metrics = [GAP, "accuracy"]
LR = 1e-4

model.compile(optimizer=RMSprop(learning_rate=LR),  
              loss=CategoricalCrossentropy(),
              metrics=metrics)

model.summary()
# Out:
# Number of layers in the pretrained model:  132
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# rescale (Sequential)         (None, 128, 128, 3)       0
# _________________________________________________________________
# xception (Functional)        (None, 4, 4, 2048)        20861480
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               16777728
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               102600
# =================================================================
# Total params: 37,741,808
# Trainable params: 16,884,424
# Non-trainable params: 20,857,384
# _________________________________________________________________

# %%
#Dictionary as a log for the hyperparemeter tuning
hyperparameters = { 
    'classes': CLASSES,
    'img_size': IMG_SIZE[0],
    'batch': BATCH_SIZE,
    'data_augmentation': False,
    'learning_rate': LR,
    'optimizer': "RMSprop",
    'epochs': FINE_TUNE_EPOCHS, 
    'freezed_layers': fine_tune_at,
    'dense': CLASSES,
    'flatten': True,
    'dense_1': 512,
    'dropout' : 0.5
}
hyperparameters
# Out:
# {'batch': 256,
#  'classes': 200,
#  'data_augmentation': False,
#  'dense': 200,
#  'dense_1': 512,
#  'dropout': 0.5,
#  'epochs': 40,
#  'flatten': True,
#  'freezed_layers': 130,
#  'img_size': 128,
#  'learning_rate': 0.0001,
#  'optimizer': 'RMSprop'}

# %%
LOG_PATH = "/content/drive/MyDrive/4º de Carrera/TFG/Experiments/log_Xception_fine_tuning.csv"
log_csv = pd.read_csv(LOG_PATH)
print(log_csv.shape)
# Out:
# (17, 21)

# %%
log_csv
# Out:
#     classes  img_size  batch  ...  dense_1  dropout dropout_1
# 0       200       128    512  ...      NaN      NaN       NaN
# 1       200       128    512  ...      NaN      NaN       NaN
# 2       200       128    512  ...    512.0      0.5       NaN
# 3       200       128    512  ...      NaN      NaN       NaN
# 4       200       128    512  ...      NaN      NaN       NaN
# 5       200       128    512  ...    512.0      0.5       NaN
# 6        20       128    256  ...      NaN      NaN       NaN
# 7        20       128    256  ...    512.0      0.5       NaN
# 8        20       128    256  ...    512.0      0.5       NaN
# 9        20       128    256  ...    512.0      0.5       NaN
# 10       20       128    256  ...      NaN      NaN       NaN
# 11       20       128    256  ...      NaN      NaN       NaN
# 12       20       128    256  ...    512.0      NaN       0.5
# 13       20       128    256  ...    512.0      NaN       0.5
# 14       20       128    256  ...      NaN      NaN       NaN
# 15      200       128    256  ...      NaN      NaN       NaN
# 16      200       128    256  ...      NaN      NaN       NaN
#
# [17 rows x 21 columns]

# %%
NUM_EXPERIMENT = log_csv.shape[0]
LOG_DIR = f"/content/drive/MyDrive/4º de Carrera/TFG/TensorBoard_Logs/Xception_fine_tuning_{NUM_EXPERIMENT}"
CHECK_POINT = f"/content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_{NUM_EXPERIMENT}.h5"

callbacks = [
      EarlyStopping(monitor="val_accuracy", verbose=1, patience=4, mode="max", restore_best_weights=True),
      ModelCheckpoint(filepath=CHECK_POINT, verbose=1, monitor="val_accuracy", mode="max", save_best_only=True),
      TensorBoard(log_dir=LOG_DIR, histogram_freq=1),
      hp.KerasCallback(LOG_DIR, hyperparameters)
]

with tf.device('/device:GPU:0'):
  history_fine = model.fit(train_dataset,
                          epochs=FINE_TUNE_EPOCHS,
                          callbacks=callbacks,
                          class_weight=class_weights,
                          validation_data=val_dataset)
# Out:
# Epoch 1/40
# 214/214 [==============================] - 194s 885ms/step - loss: 4.5742 - GAP: 0.0293 - accuracy: 0.1432 - val_loss: 2.9036 - val_GAP: 0.1639 - val_accuracy: 0.3719
#
# Epoch 00001: val_accuracy improved from -inf to 0.37194, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 2/40
# 214/214 [==============================] - 189s 880ms/step - loss: 3.1449 - GAP: 0.1156 - accuracy: 0.3301 - val_loss: 2.5029 - val_GAP: 0.2060 - val_accuracy: 0.4286
#
# Epoch 00002: val_accuracy improved from 0.37194 to 0.42859, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 3/40
# 214/214 [==============================] - 189s 879ms/step - loss: 2.6726 - GAP: 0.1683 - accuracy: 0.4046 - val_loss: 2.2913 - val_GAP: 0.2430 - val_accuracy: 0.4689
#
# Epoch 00003: val_accuracy improved from 0.42859 to 0.46892, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 4/40
# 214/214 [==============================] - 189s 879ms/step - loss: 2.3447 - GAP: 0.2195 - accuracy: 0.4615 - val_loss: 2.1516 - val_GAP: 0.2667 - val_accuracy: 0.4957
#
# Epoch 00004: val_accuracy improved from 0.46892 to 0.49566, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 5/40
# 214/214 [==============================] - 189s 879ms/step - loss: 2.1049 - GAP: 0.2568 - accuracy: 0.5011 - val_loss: 2.0584 - val_GAP: 0.2848 - val_accuracy: 0.5148
#
# Epoch 00005: val_accuracy improved from 0.49566 to 0.51483, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 6/40
# 214/214 [==============================] - 189s 880ms/step - loss: 1.9195 - GAP: 0.2948 - accuracy: 0.5369 - val_loss: 1.9800 - val_GAP: 0.2928 - val_accuracy: 0.5256
#
# Epoch 00006: val_accuracy improved from 0.51483 to 0.52557, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 7/40
# 214/214 [==============================] - 189s 879ms/step - loss: 1.7473 - GAP: 0.3294 - accuracy: 0.5674 - val_loss: 1.9377 - val_GAP: 0.3065 - val_accuracy: 0.5370
#
# Epoch 00007: val_accuracy improved from 0.52557 to 0.53703, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 8/40
# 214/214 [==============================] - 190s 880ms/step - loss: 1.6095 - GAP: 0.3633 - accuracy: 0.5965 - val_loss: 1.8881 - val_GAP: 0.3187 - val_accuracy: 0.5488
#
# Epoch 00008: val_accuracy improved from 0.53703 to 0.54882, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 9/40
# 214/214 [==============================] - 191s 889ms/step - loss: 1.4831 - GAP: 0.3942 - accuracy: 0.6215 - val_loss: 1.8533 - val_GAP: 0.3310 - val_accuracy: 0.5589
#
# Epoch 00009: val_accuracy improved from 0.54882 to 0.55885, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 10/40
# 214/214 [==============================] - 191s 888ms/step - loss: 1.3709 - GAP: 0.4244 - accuracy: 0.6479 - val_loss: 1.8321 - val_GAP: 0.3328 - val_accuracy: 0.5625
#
# Epoch 00010: val_accuracy improved from 0.55885 to 0.56248, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 11/40
# 214/214 [==============================] - 191s 888ms/step - loss: 1.2727 - GAP: 0.4553 - accuracy: 0.6698 - val_loss: 1.8067 - val_GAP: 0.3367 - val_accuracy: 0.5667
#
# Epoch 00011: val_accuracy improved from 0.56248 to 0.56675, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 12/40
# 214/214 [==============================] - 191s 888ms/step - loss: 1.1859 - GAP: 0.4795 - accuracy: 0.6902 - val_loss: 1.7914 - val_GAP: 0.3490 - val_accuracy: 0.5725
#
# Epoch 00012: val_accuracy improved from 0.56675 to 0.57251, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 13/40
# 214/214 [==============================] - 191s 889ms/step - loss: 1.1045 - GAP: 0.5082 - accuracy: 0.7083 - val_loss: 1.7751 - val_GAP: 0.3492 - val_accuracy: 0.5759
#
# Epoch 00013: val_accuracy improved from 0.57251 to 0.57588, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 14/40
# 214/214 [==============================] - 191s 888ms/step - loss: 1.0384 - GAP: 0.5261 - accuracy: 0.7211 - val_loss: 1.7487 - val_GAP: 0.3537 - val_accuracy: 0.5805
#
# Epoch 00014: val_accuracy improved from 0.57588 to 0.58047, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 15/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.9663 - GAP: 0.5492 - accuracy: 0.7369 - val_loss: 1.7531 - val_GAP: 0.3596 - val_accuracy: 0.5858
#
# Epoch 00015: val_accuracy improved from 0.58047 to 0.58578, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 16/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.9021 - GAP: 0.5734 - accuracy: 0.7531 - val_loss: 1.7517 - val_GAP: 0.3621 - val_accuracy: 0.5867
#
# Epoch 00016: val_accuracy improved from 0.58578 to 0.58669, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 17/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.8612 - GAP: 0.5867 - accuracy: 0.7613 - val_loss: 1.7644 - val_GAP: 0.3623 - val_accuracy: 0.5877
#
# Epoch 00017: val_accuracy improved from 0.58669 to 0.58766, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 18/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.8079 - GAP: 0.6106 - accuracy: 0.7774 - val_loss: 1.7548 - val_GAP: 0.3648 - val_accuracy: 0.5886
#
# Epoch 00018: val_accuracy improved from 0.58766 to 0.58863, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 19/40
# 214/214 [==============================] - 191s 888ms/step - loss: 0.7598 - GAP: 0.6266 - accuracy: 0.7894 - val_loss: 1.7446 - val_GAP: 0.3695 - val_accuracy: 0.5949
#
# Epoch 00019: val_accuracy improved from 0.58863 to 0.59491, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 20/40
# 214/214 [==============================] - 191s 888ms/step - loss: 0.7186 - GAP: 0.6429 - accuracy: 0.7998 - val_loss: 1.7419 - val_GAP: 0.3747 - val_accuracy: 0.5989
#
# Epoch 00020: val_accuracy improved from 0.59491 to 0.59886, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 21/40
# 214/214 [==============================] - 191s 888ms/step - loss: 0.6716 - GAP: 0.6582 - accuracy: 0.8102 - val_loss: 1.7509 - val_GAP: 0.3735 - val_accuracy: 0.5970
#
# Epoch 00021: val_accuracy did not improve from 0.59886
# Epoch 22/40
# 214/214 [==============================] - 191s 888ms/step - loss: 0.6327 - GAP: 0.6751 - accuracy: 0.8202 - val_loss: 1.7556 - val_GAP: 0.3721 - val_accuracy: 0.5963
#
# Epoch 00022: val_accuracy did not improve from 0.59886
# Epoch 23/40
# 214/214 [==============================] - 191s 888ms/step - loss: 0.6001 - GAP: 0.6889 - accuracy: 0.8285 - val_loss: 1.7765 - val_GAP: 0.3714 - val_accuracy: 0.5966
#
# Epoch 00023: val_accuracy did not improve from 0.59886
# Epoch 24/40
# 214/214 [==============================] - 191s 888ms/step - loss: 0.5649 - GAP: 0.7097 - accuracy: 0.8406 - val_loss: 1.7619 - val_GAP: 0.3821 - val_accuracy: 0.6025
#
# Epoch 00024: val_accuracy improved from 0.59886 to 0.60249, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 25/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.5388 - GAP: 0.7153 - accuracy: 0.8448 - val_loss: 1.7694 - val_GAP: 0.3749 - val_accuracy: 0.5984
#
# Epoch 00025: val_accuracy did not improve from 0.60249
# Epoch 26/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.5123 - GAP: 0.7276 - accuracy: 0.8516 - val_loss: 1.7756 - val_GAP: 0.3758 - val_accuracy: 0.6018
#
# Epoch 00026: val_accuracy did not improve from 0.60249
# Epoch 27/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.4789 - GAP: 0.7491 - accuracy: 0.8643 - val_loss: 1.7902 - val_GAP: 0.3787 - val_accuracy: 0.6033
#
# Epoch 00027: val_accuracy improved from 0.60249 to 0.60326, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 28/40
# 214/214 [==============================] - 191s 888ms/step - loss: 0.4579 - GAP: 0.7564 - accuracy: 0.8681 - val_loss: 1.7965 - val_GAP: 0.3786 - val_accuracy: 0.6027
#
# Epoch 00028: val_accuracy did not improve from 0.60326
# Epoch 29/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.4431 - GAP: 0.7637 - accuracy: 0.8722 - val_loss: 1.8052 - val_GAP: 0.3836 - val_accuracy: 0.6046
#
# Epoch 00029: val_accuracy improved from 0.60326 to 0.60462, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 30/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.4199 - GAP: 0.7753 - accuracy: 0.8782 - val_loss: 1.7902 - val_GAP: 0.3831 - val_accuracy: 0.6045
#
# Epoch 00030: val_accuracy did not improve from 0.60462
# Epoch 31/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.3988 - GAP: 0.7796 - accuracy: 0.8832 - val_loss: 1.8333 - val_GAP: 0.3778 - val_accuracy: 0.6031
#
# Epoch 00031: val_accuracy did not improve from 0.60462
# Epoch 32/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.3856 - GAP: 0.7943 - accuracy: 0.8888 - val_loss: 1.8296 - val_GAP: 0.3753 - val_accuracy: 0.6044
#
# Epoch 00032: val_accuracy did not improve from 0.60462
# Epoch 33/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.3651 - GAP: 0.8045 - accuracy: 0.8952 - val_loss: 1.8184 - val_GAP: 0.3841 - val_accuracy: 0.6053
#
# Epoch 00033: val_accuracy improved from 0.60462 to 0.60527, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 34/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.3537 - GAP: 0.8089 - accuracy: 0.8975 - val_loss: 1.8354 - val_GAP: 0.3795 - val_accuracy: 0.6062
#
# Epoch 00034: val_accuracy improved from 0.60527 to 0.60618, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 35/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.3371 - GAP: 0.8085 - accuracy: 0.8979 - val_loss: 1.8457 - val_GAP: 0.3840 - val_accuracy: 0.6065
#
# Epoch 00035: val_accuracy improved from 0.60618 to 0.60650, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 36/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.3186 - GAP: 0.8268 - accuracy: 0.9073 - val_loss: 1.8573 - val_GAP: 0.3764 - val_accuracy: 0.6023
#
# Epoch 00036: val_accuracy did not improve from 0.60650
# Epoch 37/40
# 214/214 [==============================] - 191s 889ms/step - loss: 0.3058 - GAP: 0.8299 - accuracy: 0.9102 - val_loss: 1.8590 - val_GAP: 0.3860 - val_accuracy: 0.6087
#
# Epoch 00037: val_accuracy improved from 0.60650 to 0.60870, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 38/40
# 214/214 [==============================] - 192s 889ms/step - loss: 0.2983 - GAP: 0.8347 - accuracy: 0.9118 - val_loss: 1.8992 - val_GAP: 0.3798 - val_accuracy: 0.6048
#
# Epoch 00038: val_accuracy did not improve from 0.60870
# Epoch 39/40
# 214/214 [==============================] - 192s 890ms/step - loss: 0.2819 - GAP: 0.8466 - accuracy: 0.9182 - val_loss: 1.8927 - val_GAP: 0.3884 - val_accuracy: 0.6114
#
# Epoch 00039: val_accuracy improved from 0.60870 to 0.61136, saving model to /content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5
# Epoch 40/40
# 214/214 [==============================] - 191s 888ms/step - loss: 0.2753 - GAP: 0.8447 - accuracy: 0.9181 - val_loss: 1.8968 - val_GAP: 0.3827 - val_accuracy: 0.6068
#
# Epoch 00040: val_accuracy did not improve from 0.61136

# %%
train_loss, train_gap, train_acc = model.evaluate(train_dataset)
# Out:
# 214/214 [==============================] - 146s 675ms/step - loss: 0.0478 - GAP: 0.9910 - accuracy: 0.9953

# %%
val_loss, val_gap, val_acc = model.evaluate(val_dataset)
# Out:
# 61/61 [==============================] - 41s 670ms/step - loss: 1.8968 - GAP: 0.3827 - accuracy: 0.6068

# %%
results = {
    'train_loss': round(train_loss,3) ,
    'train_acc': round(train_acc,3),
    'train_GAP': round(train_gap,3),
    'val_loss': round(val_loss,3),
    'val_acc': round(val_acc,3),
    'val_GAP': round(val_gap,3),    
    'model': CHECK_POINT,
    'tensorboard': LOG_DIR
}
results
# Out:
# {'model': '/content/drive/MyDrive/4º de Carrera/TFG/Models/Xception_fine_tuning_17.h5',
#  'tensorboard': '/content/drive/MyDrive/4º de Carrera/TFG/TensorBoard_Logs/Xception_fine_tuning_17',
#  'train_GAP': 0.991,
#  'train_acc': 0.995,
#  'train_loss': 0.048,
#  'val_GAP': 0.383,
#  'val_acc': 0.607,
#  'val_loss': 1.897}

# %%
log = {}
log.update(hyperparameters)
log.update(results)
# log_csv = pd.DataFrame(log, index=[0]) #Comment later
log_csv = pd.read_csv(LOG_PATH)
log_csv = log_csv.append(log,ignore_index=True)
log_csv.to_csv(LOG_PATH, index=False)

# %% [markdown]
# Analyzing the learning curves of the fine tuning process.

# %%
plot_history(history_fine)
